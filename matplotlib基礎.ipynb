# %%
import matplotlib.pyplot as plt

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.figure(figsize = (3,3))#顯示圖形大小
x = np.linspace(0, 4*np.pi, 100)
plt.subplot(211)
plt.plot(x, np.sin(x))
plt.subplot(212)
plt.plot(x, np.cos(x))

# %%
ax = plt.subplots(2,1)
ax #宣告兩個子區域，沒s不回傳，有s會傳
# Out:
# (<Figure size 640x480 with 2 Axes>, array([<Axes: >, <Axes: >], dtype=object))

# %% [markdown]
# # 0. matplotlib、pandas、seaborn 基礎視覺化

# %% [markdown]
# ## matplotlib

# %%
plt.legend?

# %%
"Noto Sans TC"
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

plt.rcParams['font.family'] = "Noto Sans TC" #要知道所使用的字型名稱
plt.figure(figsize = (10,3))
x = [1, 2, 3, 4, 5]
y = [2, 4, 6, 8, 10]
plt.bar(x, y) #長條圖
plt.xlabel('日期')
plt.ylabel('業績')
plt.title('90年業績')
plt.xlim(0,8) #改變X軸範圍
plt.ylim(0,15)
plt.legend(['每月績效'], title ='說明', frameon = True, loc = 1)
plt.savefig('1.png', bbox_inches = 'tight', dpi = 250) #輸出照片,dpi調圖片大小
# plt.show() 3.10之前版本要添加

# %%
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

font = fm.FontProperties(fname='C:\Windows\Fonts\kaiu.ttf', size = 16)
plt.figure(figsize = (10,3))
x = [1, 2, 3, 4, 5]
y = [2, 4, 6, 8, 10]
plt.bar(x, y) #長條圖
plt.xlabel('日期', fontproperties = font)
plt.ylabel('業績', fontproperties = font)
plt.title('90年業績', fontproperties = font)
plt.xlim(0,8) #改變X軸範圍
plt.ylim(0,15)
plt.legend(['每月績效'], prop = font, title ='說明', frameon = True, loc = 1)
plt.savefig('1.png', bbox_inches = 'tight', dpi = 250) #輸出照片,dpi調圖片大小
# plt.show() 3.10之前版本要添加

# %%
plt.figure(figsize = (5,3))

plt.plot(x, y) #折線圖
plt.plot(x,y, c = 'r', marker = '^', markersize = 10) #marker = 'p'/ 's' / 'v'

# %%
plt.figure(figsize = (5,3))
plt.barh(y,x) #長條圖顛倒
# Out:
# <BarContainer object of 5 artists>

# %%
plt.figure(figsize = (5,3))
plt.scatter(x,y) #散佈圖

# %% [markdown]
# ## pandas

# %%
import pandas as pd
df = pd.DataFrame({'col1': [1, 3, 5, 7, 9], 'col2': [2, 4, 6, 8, 10]})
df
# Out:
#    col1  col2
# 0     1     2
# 1     3     4
# 2     5     6
# 3     7     8
# 4     9    10

# %%
df.plot()
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt
plt.rcParams['font.family'] = 'Microsoft Yahei'

df.plot(kind='bar',
        x='col1',
        y='col2',
        figsize = (10,3),
        xlabel = '日期',
        ylabel = '業績',
        label = '每月績效',
        legend = True, 
        title = '90年業績')
# Out:
# <Axes: title={'center': '90年業績'}, xlabel='日期', ylabel='業績'>

# %%
df.plot(x='col1', y='col2', figsize = (10,3)) #折線圖
# Out:
# <Axes: xlabel='col1'>

# %%
df.plot(kind='scatter', x='col1', y='col2', figsize = (10,3))
# Out:
# <Axes: xlabel='col1', ylabel='col2'>

# %%
import pandas as pd
df = pd.DataFrame({'col1': [1, 3, 5, 7, 9],
                   'col2': [2, 4, 6, 8, 10],
                   'col3': [9, 8, 7, 6, 2]})
df
# Out:
#    col1  col2  col3
# 0     1     2     9
# 1     3     4     8
# 2     5     6     7
# 3     7     8     6
# 4     9    10     2

# %%
df[['col2','col3']].plot(figsize = (10,3))
# Out:
# <Axes: >

# %%
#Method Chaining
(df
 .set_index('col3')[['col1','col2']]
 .plot(figsize = (10,3)))
# Out:
# <Axes: xlabel='col3'>

# %%
#Method Chaining
(df
 .set_index('col3')
 .loc[:, ['col1','col2']]
 .plot(figsize = (10,3)))
# Out:
# <Axes: xlabel='col3'>

# %% [markdown]
# ## seaborn

# %%
#安裝 執行任一行
# !pip install seaborn
#!conda install seaborn

# %%
import seaborn as sns
df = pd.DataFrame({'col1': [1, 3, 5, 7, 9], 'col2': [2, 4, 6, 8, 10]})
plt.figure(figsize = (10,3))
sns.barplot(data=df, x='col1', y='col2')
# Out:
# <Axes: xlabel='col1', ylabel='col2'>

# %% [markdown]
# # matplotlib、pandas 視覺化風格
# ## matplotlib
# 調整風格
# - plt.style.use(風格名稱)
# - 所有可用風格：https://matplotlib.org/stable/gallery/style_sheets/style_sheets_reference.html

# %%
import matplotlib.pyplot as plt
x = [1, 2, 3, 4, 5]
y = [2, 4, 6, 8, 10]
#plt.style.use('seaborn-whitegrid') 這個會影響到其他pd seaborn
plt.bar(x, y)
# Out:
# <BarContainer object of 5 artists>

# %% [markdown]
# ## pandas

# %%
import pandas as pd
df = pd.DataFrame({'col1': [1, 3, 5, 7, 9], 'col2': [2, 4, 6, 8, 10]})
df.plot(kind='bar', x='col1', y='col2', grid = True)
# Out:
# <Axes: xlabel='col1'>

# %% [markdown]
# ## seaborn

# %%
import seaborn as sns
sns.barplot(data=df, x='col1', y='col2')
# Out:
# <Axes: xlabel='col1', ylabel='col2'>

# %% [markdown]
# # 1. 細說matplotlib 繪圖方式
# ### 法1：透過x, y 串列資料繪圖，x, y 串列皆需為數值資料

# %%
import matplotlib.pyplot as plt
import numpy as np

x = pd.date_range("2017-10-01", periods=10, freq = 'D')
y = np.random.randint(50, 100, size=10)
plt.figure(figsize=(15,6))
plt.plot(x, y)
plt.grid(True)
plt.show()

# %% [markdown]
# ### 法2：資料在DataFrame，x, y 串列皆需為數值資料

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

idx = pd.date_range("2017-10-01", periods=10, freq = 'D')
data = np.random.randint(50, 100, size=10)
df = pd.DataFrame({'date':idx, 'value':data})

fig, ax = plt.subplots(figsize=(15,6))
df.plot(x ='date', y = 'value', ax = ax)
plt.show()

# %% [markdown]
# # 細說Pandas 繪圖方式
# ### 搭配DataFrame，指定x 串列資料為數值資料，y為索引為字串物件

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import matplotlib.font_manager as fm
font = fm.FontProperties(fname = r'C:\Windows\Fonts\mingliu.ttc', size = 14)

idx = pd.date_range("2017-10-01", periods=10, freq = 'D').strftime("%Y/%m/%d")
data = np.random.randint(50, 100, size=10)
df = pd.DataFrame({'date':idx, 'value':data})

fig, ax = plt.subplots(1, 1, figsize=(15,6))
plt.xticks(range(0, len(df.index)), df.date)
df['value'].plot(ax = ax, label = '數值')
plt.legend(prop = font)

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import matplotlib.font_manager as fm
font = fm.FontProperties(fname = r'C:\Windows\Fonts\mingliu.ttc', size = 14)

idx = pd.date_range("2017-10-01", periods=20, freq = 'D').strftime("%Y/%m/%d")
data = np.random.randint(50, 100, size=20)
df = pd.DataFrame({'date':idx, 'value':data})
df = df.set_index('date')
df.plot(figsize = (12, 5))
plt.legend(['資料'], prop = font)
plt.xlabel('日期', fontproperties = font)
# Out:
# Text(0.5, 0, '日期')

# %% [markdown]
# # 2. matplotlib、pandas 調整字型、文字大小、配色、解析度
# # 2-0 調整字型、解析度、文字大小、配色
#
# matplotlib.rcParams
# - rc(runtime configuration)
#     - 字型（家族）：'font.family'
#     - 字型：'font.sans-serif'
#     - 解析度：'figure.dpi'
#     - 文字大小：'font.size'
#     - 配色：'axes.prop_cycle'
# - https://matplotlib.org/stable/api/matplotlib_configuration_api.html#matplotlib.rcParams

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
print('字型（家族）', mpl.rcParams['font.family'])
print('字型', mpl.rcParams['font.sans-serif'])
print('解析度', mpl.rcParams['figure.dpi'])
print('文字大小', mpl.rcParams['font.size'])
print('配色', mpl.rcParams['axes.prop_cycle'])
# Out:
# 字型（家族） ['Microsoft Yahei']
# 字型 ['DejaVu Sans', 'Bitstream Vera Sans', 'Computer Modern Sans Serif', 'Lucida Grande', 'Verdana', 'Geneva', 'Lucid', 'Arial', 'Helvetica', 'Avant Garde', 'sans-serif']
# 解析度 100.0
# 文字大小 10.0
# 配色 cycler('color', ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#8c564b', '#e377c2', '#7f7f7f', '#bcbd22', '#17becf'])

# %%
mpl.rcParams['font.family'] = 'jf-openhuninn-1.0'
mpl.rcParams['figure.dpi'] = 120
mpl.rcParams['font.size'] = 14
mpl.rcParams['axes.prop_cycle'] = mpl.cycler(color=["r", "k", "c"])

# %% [markdown]
# ### axes.prop_cycle 屬性循環

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np

# Set the default color cycle
mpl.rcParams['axes.prop_cycle'] = mpl.cycler(color = plt.cm.datad['BrBG'][5:])

x = np.linspace(0, 20, 100)

fig, axes = plt.subplots(nrows=2)

for i in range(15):
    axes[0].plot(x, i * (x - 10)**2)

for i in range(15):
    axes[1].plot(x, i * np.cos(x))

plt.show()

# %% [markdown]
# ### 色彩映射RGB數值

# %%
plt.cm.datad
# Out:
# {'Blues': ((0.9686274509803922, 0.984313725490196, 1.0),
#   (0.8705882352941177, 0.9215686274509803, 0.9686274509803922),
#   (0.7764705882352941, 0.8588235294117647, 0.9372549019607843),
#   (0.6196078431372549, 0.792156862745098, 0.8823529411764706),
#   (0.4196078431372549, 0.6823529411764706, 0.8392156862745098),
#   (0.25882352941176473, 0.5725490196078431, 0.7764705882352941),
#   (0.12941176470588237, 0.44313725490196076, 0.7098039215686275),
#   (0.03137254901960784, 0.3176470588235294, 0.611764705882353),
#   (0.03137254901960784, 0.18823529411764706, 0.4196078431372549)),
#  'BrBG': ((0.32941176470588235, 0.18823529411764706, 0.0196078431372549),
#   (0.5490196078431373, 0.3176470588235294, 0.0392156862745098),
#   (0.7490196078431373, 0.5058823529411764, 0.17647058823529413),
#   (0.8745098039215686, 0.7607843137254902, 0.49019607843137253),
#   (0.9647058823529412, 0.9098039215686274, 0.7647058823529411),
#   (0.9607843137254902, 0.9607843137254902, 0.9607843137254902),
# ...

# %%
from cycler import cycler
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

# Define a list of markevery cases and color cases to plot
cases = [None,
         8,
         (30, 8),
         [16, 24, 30],
         [0, -1],
         slice(100, 200, 3),
         0.1,
         0.3,
         1.5,
         (0.0, 0.1),
         (0.45, 0.1)]

colors = ['#1f77b4',
          '#ff7f0e',
          '#2ca02c',
          '#d62728',
          '#9467bd',
          '#8c564b',
          '#e377c2',
          '#7f7f7f',
          '#bcbd22',
          '#17becf',
          '#1a55FF']

# Configure rcParams axes.prop_cycle to simultaneously cycle cases and colors.
mpl.rcParams['axes.prop_cycle'] = cycler(markevery=cases, color=colors)

# Create data points and offsets
x = np.linspace(0, 2 * np.pi)
offsets = np.linspace(0, 2 * np.pi, 11, endpoint=False)
yy = np.transpose([np.sin(x + phi) for phi in offsets])

# Set the plot curve with markers and a title
fig = plt.figure()
ax = fig.add_axes([0.1, 0.1, 0.6, 0.75])

for i in range(len(cases)):
    ax.plot(yy[:, i], marker='o', label=str(cases[i]))
    ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)

plt.title('Support for axes.prop_cycle cycler with markevery')

plt.show()

# %% [markdown]
# matplotlib.pyplot.bar(x, height, width=0.8, bottom=None, *, align='center', data=None, **kwargs)

# %% [markdown]
# 可調整參數
# - https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.plot.html

# %% [markdown]
# # Matplotlib色彩映射、調色盤

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt

#色彩映射列表
if mpl.__version__ >= '1.5.0':
    print(plt.colormaps())
elif mpl.__version__ < '1.5.0':
    print(plt.cm.cmap_d.keys())
# Out:
# ['magma', 'inferno', 'plasma', 'viridis', 'cividis', 'twilight', 'twilight_shifted', 'turbo', 'Blues', 'BrBG', 'BuGn', 'BuPu', 'CMRmap', 'GnBu', 'Greens', 'Greys', 'OrRd', 'Oranges', 'PRGn', 'PiYG', 'PuBu', 'PuBuGn', 'PuOr', 'PuRd', 'Purples', 'RdBu', 'RdGy', 'RdPu', 'RdYlBu', 'RdYlGn', 'Reds', 'Spectral', 'Wistia', 'YlGn', 'YlGnBu', 'YlOrBr', 'YlOrRd', 'afmhot', 'autumn', 'binary', 'bone', 'brg', 'bwr', 'cool', 'coolwarm', 'copper', 'cubehelix', 'flag', 'gist_earth', 'gist_gray', 'gist_heat', 'gist_ncar', 'gist_rainbow', 'gist_stern', 'gist_yarg', 'gnuplot', 'gnuplot2', 'gray', 'hot', 'hsv', 'jet', 'nipy_spectral', 'ocean', 'pink', 'prism', 'rainbow', 'seismic', 'spring', 'summer', 'terrain', 'winter', 'Accent', 'Dark2', 'Paired', 'Pastel1', 'Pastel2', 'Set1', 'Set2', 'Set3', 'tab10', 'tab20', 'tab20b', 'tab20c', 'magma_r', 'inferno_r', 'plasma_r', 'viridis_r', 'cividis_r', 'twilight_r', 'twilight_shifted_r', 'turbo_r', 'Blues_r', 'BrBG_r', 'BuGn_r', 'BuPu_r', 'CMRmap_r', 'GnBu_r', 
# ...

# %%
[m for m in plt.cm.datad if not m.endswith("_r")]
# Out:
# ['Blues',
#  'BrBG',
#  'BuGn',
#  'BuPu',
#  'CMRmap',
#  'GnBu',
#  'Greens',
#  'Greys',
#  'OrRd',
#  'Oranges',
#  'PRGn',
#  'PiYG',
#  'PuBu',
#  'PuBuGn',
#  'PuOr',
#  'PuRd',
#  'Purples',
#  'RdBu',
#  'RdGy',
#  'RdPu',
#  'RdYlBu',
#  'RdYlGn',
#  'Reds',
#  'Spectral',
#  'Wistia',
#  'YlGn',
#  'YlGnBu',
#  'YlOrBr',
#  'YlOrRd',
#  'afmhot',
#  'autumn',
#  'binary',
#  'bone',
#  'brg',
#  'bwr',
#  'cool',
#  'coolwarm',
#  'copper',
#  'cubehelix',
#  'flag',
#  'gist_earth',
#  'gist_gray',
#  'gist_heat',
#  'gist_ncar',
#  'gist_rainbow',
#  'gist_stern',
#  'gist_yarg',
#  'gnuplot',
#  'gnuplot2',
#  'gray',
#  'hot',
#  'hsv',
#  'jet',
#  'nipy_spectral',
#  'ocean',
#  'pink',
#  'prism',
#  'rainbow',
#  'seismic',
#  'spring',
#  'summer',
#  'terrain',
#  'winter',
#  'Accent',
#  'Dark2',
#  'Paired',
#  'Pastel1',
#  'Pastel2',
#  'Set1',
#  'Set2',
#  'Set3',
#  'tab10',
#  'tab20',
#  'tab20b',
#  'tab20c']

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(4,0.4))
#col_map = plt.get_cmap(plt.colormaps()[0])
col_map = plt.get_cmap('tab10_r')
mpl.colorbar.ColorbarBase(ax, cmap=col_map, orientation = 'horizontal')
plt.show()

# %%
import matplotlib.pyplot as plt
 
cmap_list1 = plt.colormaps()
print(cmap_list1)
# Out:
# ['magma', 'inferno', 'plasma', 'viridis', 'cividis', 'twilight', 'twilight_shifted', 'turbo', 'Blues', 'BrBG', 'BuGn', 'BuPu', 'CMRmap', 'GnBu', 'Greens', 'Greys', 'OrRd', 'Oranges', 'PRGn', 'PiYG', 'PuBu', 'PuBuGn', 'PuOr', 'PuRd', 'Purples', 'RdBu', 'RdGy', 'RdPu', 'RdYlBu', 'RdYlGn', 'Reds', 'Spectral', 'Wistia', 'YlGn', 'YlGnBu', 'YlOrBr', 'YlOrRd', 'afmhot', 'autumn', 'binary', 'bone', 'brg', 'bwr', 'cool', 'coolwarm', 'copper', 'cubehelix', 'flag', 'gist_earth', 'gist_gray', 'gist_heat', 'gist_ncar', 'gist_rainbow', 'gist_stern', 'gist_yarg', 'gnuplot', 'gnuplot2', 'gray', 'hot', 'hsv', 'jet', 'nipy_spectral', 'ocean', 'pink', 'prism', 'rainbow', 'seismic', 'spring', 'summer', 'terrain', 'winter', 'Accent', 'Dark2', 'Paired', 'Pastel1', 'Pastel2', 'Set1', 'Set2', 'Set3', 'tab10', 'tab20', 'tab20b', 'tab20c', 'magma_r', 'inferno_r', 'plasma_r', 'viridis_r', 'cividis_r', 'twilight_r', 'twilight_shifted_r', 'turbo_r', 'Blues_r', 'BrBG_r', 'BuGn_r', 'BuPu_r', 'CMRmap_r', 'GnBu_r', 
# ...

# %% [markdown]
# ### 色彩映射顯示1

# %%
# !pip install colorspacious

# %%
#https://matplotlib.org/stable/tutorials/colors/colormaps.html
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
from colorspacious import cspace_converter
cmaps = {}

gradient = np.linspace(0, 1, 256)
gradient = np.vstack((gradient, gradient))

def plot_color_gradients(category, cmap_list):
    # Create figure and adjust figure height to number of colormaps
    nrows = len(cmap_list)
    figh = 0.35 + 0.15 + (nrows + (nrows - 1) * 0.1) * 0.22
    fig, axs = plt.subplots(nrows=nrows + 1, figsize=(6.4, figh))
    fig.subplots_adjust(top=1 - 0.35 / figh, bottom=0.15 / figh,
                        left=0.2, right=0.99)
    axs[0].set_title(f'{category} colormaps', fontsize=14)

    for ax, name in zip(axs, cmap_list):
        ax.imshow(gradient, aspect='auto', cmap=plt.get_cmap(name))
        ax.text(-0.01, 0.5, name, va='center', ha='right', fontsize=10,
                transform=ax.transAxes)

    # Turn off *all* ticks & spines, not just the ones with colormaps.
    for ax in axs:
        ax.set_axis_off()

    # Save colormap list for later.
    cmaps[category] = cmap_list

# %%
plot_color_gradients('Perceptually Uniform Sequential',
                     ['viridis', 'plasma', 'inferno', 'magma', 'cividis'])

# %% [markdown]
# ### 色彩映射顯示2

# %%
#https://www.osgeo.cn/matplotlib/tutorials/colors/colormaps.html
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib import cm
from colorspacious import cspace_converter
from collections import OrderedDict

cmaps = OrderedDict()

#順序
cmaps['Perceptually Uniform Sequential'] = [
            'viridis', 'plasma', 'inferno', 'magma', 'cividis']
cmaps['Sequential'] = [
            'Greys', 'Purples', 'Blues', 'Greens', 'Oranges', 'Reds',
            'YlOrBr', 'YlOrRd', 'OrRd', 'PuRd', 'RdPu', 'BuPu',
            'GnBu', 'PuBu', 'YlGnBu', 'PuBuGn', 'BuGn', 'YlGn']
#順序2
cmaps['Sequential (2)'] = [
            'binary', 'gist_yarg', 'gist_gray', 'gray', 'bone', 'pink',
            'spring', 'summer', 'autumn', 'winter', 'cool', 'Wistia',
            'hot', 'afmhot', 'gist_heat', 'copper']
#發散
cmaps['Diverging'] = [
            'PiYG', 'PRGn', 'BrBG', 'PuOr', 'RdGy', 'RdBu',
            'RdYlBu', 'RdYlGn', 'Spectral', 'coolwarm', 'bwr', 'seismic']
#循環
cmaps['Cyclic'] = ['hsv']
#'twilight', 'twilight_shifted'
#定性
cmaps['Qualitative'] = ['Pastel1', 'Pastel2', 'Paired', 'Accent',
                        'Dark2', 'Set1', 'Set2', 'Set3',
                        'tab10', 'tab20', 'tab20b', 'tab20c']
#雜項
cmaps['Miscellaneous'] = [
            'flag', 'prism', 'ocean', 'gist_earth', 'terrain', 'gist_stern',
            'gnuplot', 'gnuplot2', 'CMRmap', 'cubehelix', 'brg', 'gist_rainbow', 'rainbow']
#'jet', 'turbo', 'nipy_spectral','gist_ncar'



nrows = max(len(cmap_list) for cmap_category, cmap_list in cmaps.items())
gradient = np.linspace(0, 1, 256)
gradient = np.vstack((gradient, gradient))

def plot_color_gradients(cmap_category, cmap_list, nrows):
    fig, axes = plt.subplots(nrows=nrows)
    fig.subplots_adjust(top=0.95, bottom=0.01, left=0.2, right=0.99)
    axes[0].set_title(cmap_category + ' colormaps', fontsize=14)

    for ax, name in zip(axes, cmap_list):
        ax.imshow(gradient, aspect='auto', cmap=plt.get_cmap(name))
        pos = list(ax.get_position().bounds)
        x_text = pos[0] - 0.01
        y_text = pos[1] + pos[3]/2.
        fig.text(x_text, y_text, name, va='center', ha='right', fontsize=10)

    # Turn off *all* ticks & spines, not just the ones with colormaps.
    for ax in axes:
        ax.set_axis_off()


for cmap_category, cmap_list in cmaps.items():
    plot_color_gradients(cmap_category, cmap_list, nrows)

plt.show()

# %% [markdown]
# ### 色彩映射顯示3

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt

def plot_colorMaps(cmap):
    fig, ax = plt.subplots(figsize=(4,0.4))
    col_map = plt.get_cmap(cmap)
    mpl.colorbar.ColorbarBase(ax, cmap=col_map, orientation = 'horizontal')

    plt.show()

for cmap_id in plt.colormaps():
    print(cmap_id)
    plot_colorMaps(cmap_id)
# Out:
# magma
# inferno
# plasma
# viridis
# cividis
# twilight
# twilight_shifted
# turbo
# Blues
# BrBG
# BuGn
# BuPu
# CMRmap
# GnBu
# Greens
# Greys
# OrRd
# Oranges
# PRGn
# PiYG
# PuBu
# PuBuGn
# PuOr
# PuRd
# Purples
# RdBu
# RdGy
# RdPu
# RdYlBu
# RdYlGn
# Reds
# Spectral
# Wistia
# YlGn
# YlGnBu
# YlOrBr
# YlOrRd
# afmhot
# autumn
# binary
# bone
# brg
# bwr
# cool
# coolwarm
# copper
# cubehelix
# flag
# gist_earth
# gist_gray
# gist_heat
# gist_ncar
# gist_rainbow
# gist_stern
# gist_yarg
# gnuplot
# gnuplot2
# gray
# hot
# hsv
# jet
# nipy_spectral
# ocean
# pink
# prism
# rainbow
# seismic
# spring
# summer
# terrain
# winter
# Accent
# Dark2
# Paired
# Pastel1
# Pastel2
# Set1
# Set2
# Set3
# tab10
# tab20
# tab20b
# tab20c
# magma_r
# inferno_r
# plasma_r
# viridis_r
# cividis_r
# twilight_r
# twilight_shifted_r
# turbo_r
# Blues_r
# BrBG_r
# BuGn_r
# BuPu_r
# CMRmap_r
# GnBu_r
# Greens_r
# Greys_r
# OrRd_r
# Oranges_r
# PRGn_r
# PiYG_r
# PuBu_r
# PuBuGn_r
# PuOr_r
# PuRd_r
# ...

# %% [markdown]
# # 2-1 matplotlib繪圖無法支援中文字型
# ## 問題原因：matplotlib支援unicode編碼，因為沒有找到合適的中文字體，所以無法顯示中文字
# ## 解決方式：透過以下3種方法設定解解決顯示中文字問題
#
# 1. 修改繪圖設定檔matplotlibrc
# 2. 動態修改繪圖設定檔：rcParams、matplotlib.rc()
# 3. 動態載入系統中文字型

# %% [markdown]
# ### 2-1-1 修改matplotlib繪圖設定檔
# - matplotlib繪圖時，依據以下路徑順序尋找繪圖設定檔(matplotlibrc)位置，來進行繪圖相關屬性設定，如視圖視窗大小以及每英寸點數[dpi]，線條寬度，顏色和樣式，坐標軸，坐標和網格屬性，文本，字體等屬性。
# - [matplotlib configuration and cache directory locations](https://matplotlib.org/faq/troubleshooting_faq.html#locating-matplotlib-config-dir)
#
# ## 操作如下
# ### 1. 取得matplotlib繪圖設定檔路徑
# ```python
# import matplotlib
# print(matplotlib.matplotlib_fname())
# ```
# ### 2.  在matplotlib的繪圖設定檔尋找 *font.sans-serif*，位置添加字型名稱
# - #font.sans-serif     : Bitstream Vera Sans, Lucida Grande, Verdana, Geneva, Lucid, Arial, Helvetica, Avant Garde, sans-serif
#
# ### 3. 移除 "#"
# ### 4. 加入字型名稱
# ### 5.  設定檔修改存檔，關閉重啟Jupyter notebook

# %%
# 系統設定路徑
import matplotlib
print(matplotlib.matplotlib_fname())
# Out:
# C:\Users\Lo yuan\anaconda3\lib\site-packages\matplotlib\mpl-data\matplotlibrc

# %% [markdown]
# 找到目前的 matplotlib 所預設的字體是什麼以及位置，或新增字體放至matplotlib指定字體路徑

# %%
from matplotlib.font_manager import findfont, FontProperties
findfont(FontProperties(family=FontProperties().get_family()))
# Out:
# 'C:\\Users\\Lo yuan\\anaconda3\\Lib\\site-packages\\matplotlib\\mpl-data\\fonts\\ttf\\DejaVuSans.ttf'

# %% [markdown]
# ### 查詢 matplotlib 的繪圖設定預設值 rcParams

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
print(mpl.rc_params())
# Out:
# _internal.classic_mode: False
# agg.path.chunksize: 0
# animation.bitrate: -1
# animation.codec: h264
# animation.convert_args: []
# animation.convert_path: convert
# animation.embed_limit: 20.0
# animation.ffmpeg_args: []
# animation.ffmpeg_path: ffmpeg
# animation.frame_format: png
# animation.html: none
# animation.writer: ffmpeg
# axes.autolimit_mode: data
# axes.axisbelow: line
# axes.edgecolor: black
# axes.facecolor: white
# axes.formatter.limits: [-5, 6]
# axes.formatter.min_exponent: 0
# axes.formatter.offset_threshold: 4
# axes.formatter.use_locale: False
# axes.formatter.use_mathtext: False
# axes.formatter.useoffset: True
# axes.grid: False
# axes.grid.axis: both
# axes.grid.which: major
# axes.labelcolor: black
# axes.labelpad: 4.0
# axes.labelsize: medium
# axes.labelweight: normal
# axes.linewidth: 0.8
# axes.prop_cycle: cycler('color', ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#8c564b', '#e377c2', '#7f7f7f', '#bcbd22', '#17becf'])
# ...

# %%
import matplotlib as mpl
mpl.rcParams
# Out:
# RcParams({'_internal.classic_mode': False,
#           'agg.path.chunksize': 0,
#           'animation.bitrate': -1,
#           'animation.codec': 'h264',
#           'animation.convert_args': [],
#           'animation.convert_path': 'convert',
#           'animation.embed_limit': 20.0,
#           'animation.ffmpeg_args': [],
#           'animation.ffmpeg_path': 'ffmpeg',
#           'animation.frame_format': 'png',
#           'animation.html': 'none',
#           'animation.writer': 'ffmpeg',
#           'axes.autolimit_mode': 'data',
#           'axes.axisbelow': 'line',
#           'axes.edgecolor': 'black',
#           'axes.facecolor': 'white',
#           'axes.formatter.limits': [-5, 6],
#           'axes.formatter.min_exponent': 0,
#           'axes.formatter.offset_threshold': 4,
#           'axes.formatter.use_locale': False,
#           'axes.formatter.use_mathtext': False,
#           'axes.formatter.useoffset': True,
#           'axes.grid': False,
# ...

# %% [markdown]
# ### 2-1-2 動態修改繪圖設定檔rcParams
# ### 透過 plt.rcParams設定matplotlib繪圖設定檔，該設定只在繪圖當下改變設定值，程式結束後不會儲存。
# - plt.rcParams 添加字型宣告方式
#
# ```python
# %pylab inline
# plt.rcParams['font.sans-serif'] #直接修改matplotlibrc設定檔中，'font.sans-serif'設定內容
# plt.rcParams['axes.unicode_minus'] = False #解決座標軸負數的負號顯示問題
# ```

# %%
# %pylab inline

#支援中文字顯示
plt.rcParams['font.family'] = 'SimHei'  #用來正常顯示中文標籤，微軟雅黑體，['SimHei']
plt.rcParams['axes.unicode_minus'] = False #解決座標軸負數的負號顯示問題
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ## 查看目前 matplotlib 可用的字型

# %%
#查詢目前系統字型
import matplotlib.font_manager
fontlist = sorted([f.name for f in matplotlib.font_manager.fontManager.ttflist])
for i in fontlist:
    print(i, end = '\t')
# Out:
# AGA Arabesque	AGA Arabesque Desktop	AIGDT	AMGDT	AcadEref	Agency FB	Agency FB	Akhbar MT	Akhbar MT	Algerian	AmdtSymbols	Ami R	Arial	Arial	Arial	Arial	Arial	Arial	Arial	Arial	Arial	Arial Rounded MT Bold	Bahnschrift	BankGothic Lt BT	BankGothic Md BT	Baskerville Old Face	Bauhaus 93	Bell MT	Bell MT	Bell MT	Berlin Sans FB	Berlin Sans FB	Berlin Sans FB Demi	Bernard MT Condensed	Blackadder ITC	Bodoni MT	Bodoni MT	Bodoni MT	Bodoni MT	Bodoni MT	Bodoni MT	Bodoni MT	Bodoni MT	Bodoni MT	Bodoni MT	Bodoni MT	Bold Italic Art	Book Antiqua	Book Antiqua	Book Antiqua	Book Antiqua	Bookman Old Style	Bookman Old Style	Bookman Old Style	Bookman Old Style	Bookshelf Symbol 7	Bradley Hand ITC	Britannic Bold	Broadway	Brush Script MT	Calibri	Calibri	Calibri	Calibri	Calibri	Calibri	Californian FB	Californian FB	Californian FB	Calisto MT	Calisto MT	Calisto MT	Calisto MT	Cambria	Cambria	Cambria	Cambria	Candara	Candara	Candara	Candara	Candara	Candara	Castellar	Centaur	Century	Century Gothic	Century Gothic	Century Got
# ...

# %% [markdown]
# ## 尋找系統已安裝的字型

# %%
from matplotlib import font_manager
font_manager.findSystemFonts(fontpaths=None, fontext="ttf")
# Out:
# ['C:\\Windows\\Fonts\\tahomabd.ttf',
#  'C:\\Windows\\Fonts\\corbelz.ttf',
#  'C:\\Windows\\Fonts\\romand__.ttf',
#  'C:\\Windows\\Fonts\\GILSANUB.TTF',
#  'C:\\Windows\\Fonts\\romanc__.ttf',
#  'C:\\Windows\\Fonts\\PERB____.TTF',
#  'C:\\Windows\\Fonts\\STLITI.TTF',
#  'C:\\Windows\\Fonts\\msjhl.ttc',
#  'C:\\Windows\\Fonts\\MOD20.TTF',
#  'C:\\Windows\\Fonts\\seguihis.ttf',
#  'C:\\Windows\\Fonts\\consolaz.ttf',
#  'C:\\Windows\\Fonts\\sanss___.ttf',
#  'C:\\Windows\\Fonts\\GARABD.TTF',
#  'C:\\Windows\\Fonts\\AMGDT___.ttf',
#  'C:\\Windows\\Fonts\\calibril.ttf',
#  'C:\\Windows\\Fonts\\SitkaI.ttc',
#  'C:\\Windows\\Fonts\\CALIST.TTF',
#  'C:\\Windows\\Fonts\\framd.ttf',
#  'C:\\Windows\\Fonts\\isoct3__.ttf',
#  'C:\\Windows\\Fonts\\georgia.ttf',
#  'C:\\Windows\\Fonts\\MTCORSVA.TTF',
#  'C:\\Windows\\Fonts\\ENGR.TTF',
#  'C:\\Windows\\Fonts\\GOUDOS.TTF',
#  'C:\\Windows\\Fonts\\simsunb.ttf',
#  'C:\\Windows\\Fonts\\Gabriola.ttf',
#  'C:\\Windows\\Fonts\\seguibli.ttf',
# ...

# %% [markdown]
# ##  找出系統適用的中文字體名稱
#
# ### 透過檔案大小大於 1M挑選，原因中文字用 2Byte 儲存要比英文字用 1Byte 來的大，中文字大於1MB
# ### 以os套件取得檔案大小
# - os.stat(檔案路徑).st_size
# - os.path.getsize(檔案路徑)

# %%
from matplotlib.font_manager import fontManager
import pandas as pd
import os

fontlist = sorted([f.name for f in fontManager.ttflist if os.path.exists(f.fname) and os.stat(f.fname).st_size>1e6])
pd.unique(fontlist).tolist()
# Out:
# ['Arial',
#  'Calibri',
#  'Cambria',
#  'DFKai-SB',
#  'FZShuTi',
#  'FZYaoTi',
#  'Gabriola',
#  'HYGothic-Extra',
#  'HYGothic-Medium',
#  'HYGraphic-Medium',
#  'HYGungSo-Bold',
#  'HYHeadLine-Medium',
#  'HYMyeongJo-Extra',
#  'HYPMokGak-Bold',
#  'HYPost-Light',
#  'HYPost-Medium',
#  'HYSinMyeongJo-Medium',
#  'LiSu',
#  'MS Gothic',
#  'Malgun Gothic',
#  'Microsoft JhengHei',
#  'Microsoft YaHei',
#  'MingLiU',
#  'MingLiU-ExtB',
#  'MoeumT R',
#  'New Gulim',
#  'Nirmala UI',
#  'Pyunji R',
#  'STCaiyun',
#  'STFangsong',
#  'STHupo',
#  'STKaiti',
#  'STLiti',
#  'STSong',
#  'STXihei',
#  'STXingkai',
#  'STXinwei',
#  'STZhongsong',
#  'Segoe UI Emoji',
#  'Segoe UI Historic',
#  'Segoe UI Symbol',
#  'SimSun',
#  'SimSun-ExtB',
#  'Times New Roman',
#  'Yet R',
#  'YouYuan',
#  'Yu Gothic']

# %%
import matplotlib.font_manager
import numpy as np
import os
fontlist = sorted([f.name for f in matplotlib.font_manager.fontManager.ttflist
                   if os.path.exists(f.fname) and os.stat(f.fname).st_size>1e6])
np.unique(fontlist).tolist()
# Out:
# ['Arial',
#  'Calibri',
#  'Cambria',
#  'DFKai-SB',
#  'FZShuTi',
#  'FZYaoTi',
#  'Gabriola',
#  'HYGothic-Extra',
#  'HYGothic-Medium',
#  'HYGraphic-Medium',
#  'HYGungSo-Bold',
#  'HYHeadLine-Medium',
#  'HYMyeongJo-Extra',
#  'HYPMokGak-Bold',
#  'HYPost-Light',
#  'HYPost-Medium',
#  'HYSinMyeongJo-Medium',
#  'LiSu',
#  'MS Gothic',
#  'Malgun Gothic',
#  'Microsoft JhengHei',
#  'Microsoft YaHei',
#  'MingLiU',
#  'MingLiU-ExtB',
#  'MoeumT R',
#  'New Gulim',
#  'Nirmala UI',
#  'Pyunji R',
#  'STCaiyun',
#  'STFangsong',
#  'STHupo',
#  'STKaiti',
#  'STLiti',
#  'STSong',
#  'STXihei',
#  'STXingkai',
#  'STXinwei',
#  'STZhongsong',
#  'Segoe UI Emoji',
#  'Segoe UI Historic',
#  'Segoe UI Symbol',
#  'SimSun',
#  'SimSun-ExtB',
#  'Times New Roman',
#  'Yet R',
#  'YouYuan',
#  'Yu Gothic']

# %%
import matplotlib.font_manager
import os
set(sorted([f.name for f in matplotlib.font_manager.fontManager.ttflist
                   if os.path.exists(f.fname) and os.stat(f.fname).st_size>1e6]))
# Out:
# {'Arial',
#  'Calibri',
#  'Cambria',
#  'DFKai-SB',
#  'FZShuTi',
#  'FZYaoTi',
#  'Gabriola',
#  'HYGothic-Extra',
#  'HYGothic-Medium',
#  'HYGraphic-Medium',
#  'HYGungSo-Bold',
#  'HYHeadLine-Medium',
#  'HYMyeongJo-Extra',
#  'HYPMokGak-Bold',
#  'HYPost-Light',
#  'HYPost-Medium',
#  'HYSinMyeongJo-Medium',
#  'LiSu',
#  'MS Gothic',
#  'Malgun Gothic',
#  'Microsoft JhengHei',
#  'Microsoft YaHei',
#  'MingLiU',
#  'MingLiU-ExtB',
#  'MoeumT R',
#  'New Gulim',
#  'Nirmala UI',
#  'Pyunji R',
#  'STCaiyun',
#  'STFangsong',
#  'STHupo',
#  'STKaiti',
#  'STLiti',
#  'STSong',
#  'STXihei',
#  'STXingkai',
#  'STXinwei',
#  'STZhongsong',
#  'Segoe UI Emoji',
#  'Segoe UI Historic',
#  'Segoe UI Symbol',
#  'SimSun',
#  'SimSun-ExtB',
#  'Times New Roman',
#  'Yet R',
#  'YouYuan',
#  'Yu Gothic'}

# %% [markdown]
# ## 直接透過畫布顯示可用的中文字

# %%
from matplotlib.font_manager import fontManager
import matplotlib.pyplot as plt
import os
import warnings
warnings.filterwarnings('ignore')

fig = plt.figure(figsize=(15,8))
ax = fig.add_subplot(111)
plt.subplots_adjust(0.04, 0.04, 0.99, 0.95, 0, 0)
plt.xticks([])
plt.yticks([])
x, y = 0.05, 0.18
fonts = [font.name for font in fontManager.ttflist if os.path.exists(font.fname) and os.stat(font.fname).st_size>1e6]
font = set(fonts)
dy = (1.0-y)/(len(fonts)/4 + (len(fonts)%4!=0))
for font in fonts:
    ax.text(x, y, font+" : 中文字體", {'fontname':font, 'fontsize':14}, transform=ax.transAxes)
    ax.text(x, y-dy/2, font, transform=ax.transAxes)
    x += 0.25
    if x >= 1.0:
        y += dy
        x = 0.05
ax.set_xlabel('X軸座標', {'fontname':'SimHei', 'fontsize':20})
ax.set_ylabel('Y軸座標', {'fontname':'SimHei', 'fontsize':20})
plt.show()
# Out:
# findfont: Font family 'SimHei' not found.
# findfont: Font family 'SimHei' not found.
# findfont: Font family 'SimHei' not found.
# findfont: Font family 'SimHei' not found.
# findfont: Font family 'SimHei' not found.
# findfont: Font family 'SimHei' not found.
# findfont: Font family 'SimHei' not found.
# findfont: Font family 'SimHei' not found.

# %% [markdown]
# ## 範例

# %% [markdown]
# $\frac{5}{17}$
# $$\frac{5}{17}$$
# https://latexeditor.lagrida.com/

# %%
# %pylab inline

plt.rcParams['font.sans-serif'] = 'Microsoft Yahei'  #用來正常顯示中文標籤，微軟雅黑體，['SimHei']
plt.rcParams['axes.unicode_minus'] = False #用來正常顯示正負號

x = np.linspace(-5,5,500)
y = power(e, x)

#frameon：邊框顯示
fig = plt.figure(figsize=(8,8), linewidth=10, edgecolor="red", frameon=True)
plt.plot(x, y, 'g--', lw=2, label='yoyo')
plt.legend(loc=0, fontsize=16)
plt.title('-5到5取500個點', fontsize=16)
plt.xlabel('-5到5數列', fontsize=16)
plt.ylabel(r'$\frac{5}{17}$', fontsize=16)
text(3, 7.5, r'$e^x$', fontsize=16)
#儲存圖片
fig.savefig("指數函數.png", edgecolor = fig.get_edgecolor())
# Out:
# %pylab is deprecated, use %matplotlib inline and import the required libraries.
# Populating the interactive namespace from numpy and matplotlib

# %%
# %pylab inline
import pandas as pd

plt.rcParams['font.sans-serif'] = 'SimHei'#'Microsoft YaHei'  #用來正常顯示中文標籤，微軟雅黑體，['SimHei']
plt.rcParams['axes.unicode_minus'] = False #用來正常顯示正負號
plt.rcParams['lines.linewidth'] = 2
plt.rcParams['lines.color'] = 'r'
plt.rcParams['figure.figsize'] = (10, 10)

x = pd.period_range("2017-06-01", periods = 200, freq = 'd')
x = x.to_timestamp().to_pydatetime() #to_pydatetime 是將 datetime64 轉 datetime
y = np.random.randn(200, 3).cumsum(0)# 產生三組，每組 200 個隨機常態分布元素

plt.plot(x, y)
plt.title('200 個隨機常態分布元素', fontsize = 16)
plt.xlabel('日期', fontsize = 16)
plt.ylabel('範圍', fontsize = 16)
plt.xticks(fontsize = 12)
plt.yticks(fontsize = 16)
#plt.savefig('sample.pdf')
savefig('sample.JPG', dpi = 200) #可以存PNG、JPG、EPS、SVG、PGF、PDF
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ### 2-1-3 動態修改繪圖設定檔matplotlib.rc()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0, 10, 1000)
y = np.sin(x)
z = np.cos(x**2)
plt.figure(figsize=(8, 4))
plt.plot(x, y, label = "$sin(x)$", color = "red", linewidth = 2)
plt.plot(x, z, "b--", label = "$cos(x^2)$")

#plt.rcParams['font.family'] = 'DFKai-SB'
font = {'family' : 'DFKai-SB',
        'weight' : 'bold',
        'size'  : '16'}
plt.rc('font', **font)              # 步驟一（設定字型的更多屬性）
plt.rc('axes', unicode_minus = False) # 步驟二（解決座標軸負數的負號顯示問題）
plt.xlabel("x軸")
plt.ylabel("y軸")
plt.title("標題")
plt.ylim(-1.2, 1.2)
plt.legend()
plt.show()

# %% [markdown]
# ### 2-1-4 指定系統上中文字型路徑

# %% [markdown]
# ## 操作方式
#
# ### 1. 到系統中找字型存放路徑
# - Windows：C:\Windows\Fonts\
# - Mac：/System/Library/Fonts
# - Linux：/usr/share/fonts
#
# ### 2. 取得所需字型檔(ttf、ttc) 完整路徑
# - Win7字型檔為ttf
# - Win8.1、Win10環境 ttf 要改為 ttc，msjh.ttc為微軟正黑體
#
# ### 3. 加入程式碼中
# ```Python
# import matplotlib.font_manager as fm
# font = fm.FontProperties(fname = r'C:\Windows\Fonts\msjh.ttc')
# ```

# %%
plt.legend?

# %%
#%pylab inline
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
font = fm.FontProperties(fname = r'C:\Windows\Fonts\mingliu.ttc', size = 20)

x = linspace(-5, 5, 2000)
plt.plot(x, sinc(x))

#plt.gcf().set_size_inches(10, 5)
plt.title('sinc(x)圖形', fontproperties = font)
plt.xlabel('-5到5範圍', fontproperties = font)
plt.ylabel('sinc(x)', fontproperties = font)
plt.legend(['sinc(x)'], prop = font)
plt.show()
savefig('sample.jpg')

# %% [markdown]
# # 依作業系統處理中文字顯示

# %%
# %pylab inline

import platform
import matplotlib.font_manager as fm
plt.rcParams['axes.unicode_minus'] = False #用來正常顯示正負號

#依據作業系統設定字型
sysstr = platform.system()
if(sysstr =="Windows"):
    if (platform.release == '7'):
        plt.rcParams['font.sans-serif'] = 'Microsoft YaHei'
    elif (platform.release == '8' or platform.release == '8.1'):
        plt.rcParams['font.sans-serif'] = 'SimHei'
        font = fm.FontProperties(fname = r'C:\Windows\Fonts\msjh.ttc', size = 20)
    else:
        plt.rcParams['font.sans-serif'] = 'SimHei'
        font = fm.FontProperties(fname = r'C:\Windows\Fonts\msjh.ttc', size = 20)
elif(sysstr == "Linux"):
    print ("Linux")
elif(sysstr == "Darwin"):
    print ("Mac os")
else:
    print ("其他系統")

# %% [markdown]
# ### 2-1-5 新增字型
#
# ### 方法1：將字型新增到 matplotlib 可用字型的列表中（僅在程式運行時有效）
# matplotlib.font_manager.fontManager.addfont(字型路徑)

# %%
from matplotlib import font_manager
fontManager.addfont('/Users/hssyuds/Library/Fonts/GenJyuuGothic-Regular.ttf')

# %%
from matplotlib.font_manager import fontManager
[f.name for f in fontManager.ttflist]

# %% [markdown]
# ### 方法2
# 1. 安裝完新字型後，將以下路徑資料夾中 fontlist-vxxx.json 的相關快取（cache）檔案都刪除。
# 2. 重新啟動此程式、列出字型，matplotlib 即會自動新增 fontlist-vxxx.json 快取檔案，即可使用新字型。

# %%
import matplotlib as mpl
mpl.get_cachedir()
# Out:
# 'C:\\Users\\USER\\.matplotlib'

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# # 3. 多重視窗
#
# ![](image\subplots.png)

# %% [markdown]
# # 3-1 子圖plt.axes
#
# plt.axes(left, bottom, width, height)
# - left：子圖左邊位置，範圍0~1
# - bottom：子圖下面位置，範圍0~1
# - width：圖的寬度，範圍0~1
# - height：圖的高度，範圍0~1
# - plt.axes(left, bottom, width, height) (左、下、寬、高)，範圍從左下角的0到右上角的1。
# - plt.axes([0.65, 0.65, 0.2, 0.2]) 從軸的寬度65%和圖的高度65%開始繪圖，往右上角繪製寬度20%與高度20%的子圖
# 語法：https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.axes.html

# %%
import matplotlib.pyplot as plt

plt.figure(figsize = (5, 3))
plt.axes()
plt.axes([0.3, 0.3, 0.3, 0.4])
plt.show()

# %%
# %pylab inline

plt.figure(figsize = (8, 8))
plt.axes()
plt.axes([0.6, 0.6, 0.2, 0.2]) #繪圖比例是0.2，實際長度是1.6
plt.show()
# Out:
# %pylab is deprecated, use %matplotlib inline and import the required libraries.
# Populating the interactive namespace from numpy and matplotlib

# %%
# %pylab inline
#fig.add_axes([x0, y0, width, height])
plt.rcParams['axes.unicode_minus'] = False
fig = plt.figure()
ax1 = fig.add_axes([0.1, 0.5, 0.8, 0.4], xticklabels=[], ylim=(-1.2, 1.2))
ax2 = fig.add_axes([0.1, 0.1, 0.8, 0.4], ylim=(-1.2, 1.2))
x = np.linspace(0, 10)
ax1.plot(np.sin(x))
ax2.plot(np.cos(x))
plt.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # 3-2 網格圖 plt.subplot
# - 建立的網格子圖行數、列數和索引值，索引值從 1 開始，從左上角到 右下角依次增加編號
# - 一次僅產生一個子圖
#
# plt.subplot(nrows, ncols, index)
# - nrows：子圖產生的row數
# - ncols：子圖產生的col數
# - index：子圖編號
# - 寫法：plt.subplot(1, 1, 1)或plt.subplot(111)
# - 語法：https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.subplot.html

# %%
plt.subplot(2, 1, 1)
plt.plot([1,2,3,4,5,6])

# %%
fig, ax = plt.subplots(2, 1)
ax[0].plot([1,2,3,4,5,6,7])
ax[1].plot([7,6,5,4,3,2,1])

# %%
fig, ax = plt.subplots(2, 2)
ax[0,0].plot([1,2,3,4,5,6,7])
ax[0,0].text(3, 3, '(0,0)')

ax[0,1].plot([7,6,5,4,3,2,1])
ax[0,1].text(3, 3, '(0,1)')

ax[1,0].bar(x = [1,2,3,4,5,6,7], height = [7,6,5,4,3,2,1])
ax[1,0].text(3, 3, '(1,0)')

ax[1,1].barh(y = [7,6,5,4,3,2,1], width = [7,6,5,4,3,2,1])
ax[1,1].text(3, 3, '(1,1)')

plt.subplots_adjust(wspace=0.2 ,hspace=0.3)

# %%
# %pylab inline
x1 = np.arange(0, 360, 5)
y1 = np.sin(x1 * np.pi/180.0)
x2 = x1
y2 = np.cos(x2 * np.pi / 180.0)

plt.subplot(231)
plt.plot(x1, y1, lw = 3)
plt.xlim(-30, 390)
plt.ylim(-1.5, 1.5)

plt.subplot(232)
plt.plot(x2, y2, 'ro')
plt.xlim(-10, 360)
plt.ylim(-1.2, 1.2)

plt.subplot(233)
plt.plot(x2, y2, 'ko')
plt.xlim(0, 50)
plt.ylim(-1.2, 1.2)

plt.subplot(234)
plt.plot(x2, y2, 'b+')
plt.xlim(0, 180)
plt.ylim(-1.2, 1.2)

plt.subplot(236)
plt.plot(x2, y2, 'g*')
plt.xlim(180, 360)
plt.ylim(-1.2, 1.2)
# Out:
# Populating the interactive namespace from numpy and matplotlib
# (-1.2, 1.2)

# %% [markdown]
# # 3-3 fig.add_subplot：另一個與plt.subplot 類似功能子圖設定
# - plt.subplot 會刪除已存在的子圖
# - fig.add_subplot 會保留子圖及軸

# %%
import matplotlib.pyplot as plt
fig = plt.figure()
fig.subplots_adjust(hspace = 0.4, wspace = 0.4) #調整子圖之間的間隔
for i in range(1, 7):
    ax = fig.add_subplot(2, 3, i)
    ax.text(0.5, 0.5, str((2, 3, i)), fontsize = 18, ha = 'center')
plt.show()

# %%
from scipy import randn
import matplotlib.pyplot as plt

fig = plt.figure(figsize = (10, 8))
ax1 = fig.add_subplot(2,2,3)
ax2 = fig.add_subplot(2,2,4)

ax1.plot(randn(1000).cumsum())
ax2.plot(randn(180).cumsum())

ticks = ax1.set_xticks([0,250,500,750,1000])
labels = ax1.set_xticklabels(['one','two','three','four','five'], rotation = 30, fontsize = 'small')

ax1.set_title('plot1')
ax2.set_title('plot2')
ax1.set_xlabel('digital')
ax2.set_xlabel('digita2')
fig.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.

# %% [markdown]
# # 3-4 快速建立網格plt.subplots
# - 一次產生 mxn 數量的子圖，並回傳fig、axes
#
# plt.subplots(nrows=1, ncols=1)
# - nrows：子圖產生的row數
# - ncols：子圖產生的col數
# - 語法：https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.subplots.html

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots(2, 3, sharex='col', sharey='row')
for i in range(2):
    for j in range(3):
        ax[i, j].text(0.5, 0.5, str((i, j)), fontsize=18, ha='center')

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots(2, 3, sharex='col', sharey='row')
for i in range(2):
    for j in range(3):
        ax[i][j].text(0.5, 0.5, str((i, j)), fontsize=18, ha='center')
fig

# %% [markdown]
# # 3-5 複雜排列方式plt.GridSpec
# - 可產生不規則的多行多列子圖。

# %% [markdown]
# plt.GridSpec(nrows, ncols, wspace, hspace)
# - nrows：指定Row數
# - ncols：指定Column數
# - wspace：兩個子圖的寬度距離
# - hspace：兩個子圖的高度距離
# - 語法：https://matplotlib.org/stable/api/_as_gen/matplotlib.gridspec.GridSpec.html

# %%
import matplotlib.pyplot as plt
grid = plt.GridSpec(4, 5, wspace = 0.4, hspace = 0.3)
plt.figure(figsize = (12, 10))
plt.subplot(grid[0, 0])
plt.text(0.5, 0.5, str((0, 0)), fontsize=18, ha='center')
plt.subplot(grid[0, 1])
plt.text(0.5, 0.5, str((0, 1)), fontsize=18, ha='center')
plt.subplot(grid[0, 2])
plt.text(0.5, 0.5, str((0, 2)), fontsize=18, ha='center')
plt.subplot(grid[0, 3])
plt.text(0.5, 0.5, str((0, 3)), fontsize=18, ha='center')
plt.subplot(grid[1, :1])
plt.text(0.5, 0.5, str('1, :1'), fontsize=18, ha='center')
plt.subplot(grid[1, 1:4])
plt.text(0.5, 0.5, str('1,1:4'), fontsize=18, ha='center')
plt.subplot(grid[2, :2])
plt.text(0.5, 0.5, str('2, :2'), fontsize=18, ha='center')
plt.subplot(grid[2, 2:4])
plt.text(0.5, 0.5, str('2, 2:4'), fontsize=18, ha='center')
plt.subplot(grid[3, :3])
plt.text(0.5, 0.5, str('3, :3'), fontsize=18, ha='center')
plt.subplot(grid[3, 3:4])
plt.text(0.5, 0.5, str('3, 3:4'), fontsize=18, ha='center')
plt.subplot(grid[:3, 4:])
plt.text(0.5, 0.5, str(':3, 4:'), fontsize=18, ha='center')
plt.subplot(grid[3:, 4])
plt.text(0.5, 0.5, str('3:, 4'), fontsize=18, ha='center')
plt.show()

# %% [markdown]
# # 3-6 subplot2grid

# %% [markdown]
# plt.subplot2grid(shape, loc, rowspan=1, colspan=1)
# - shape：指定形狀(row, column)
# - loc：指定位置(row, column)
# - rowspan：row合併
# - colspan：column合併
# - 語法：https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.subplot2grid.html

# %%
import matplotlib.pyplot as plt

fig = plt.figure()
ax1 = plt.subplot2grid((3,3), (0,0), colspan=2, rowspan=2) # topleft
ax1.text(0.5, 0.5, str('0,0'), fontsize=18, ha='center')
ax3 = plt.subplot2grid((3,3), (0,2), rowspan=3)            # right
ax3.text(0.5, 0.5, str('0,2'), fontsize=18, ha='center')
ax4 = plt.subplot2grid((3,3), (2,0))                       # bottom left
ax4.text(0.5, 0.5, str('2,0'), fontsize=18, ha='center')
ax5 = plt.subplot2grid((3,3), (2,1))                       # bottom right
ax5.text(0.5, 0.5, str('2,1'), fontsize=18, ha='center')
fig.tight_layout()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Setup the subplot2grid Layout
fig = plt.figure(figsize=(10, 5))
ax1 = plt.subplot2grid((2,4), (0,0))
ax2 = plt.subplot2grid((2,4), (0,1))
ax3 = plt.subplot2grid((2,4), (0,2))
ax4 = plt.subplot2grid((2,4), (0,3))
ax5 = plt.subplot2grid((2,4), (1,0), colspan=2)
ax6 = plt.subplot2grid((2,4), (1,2))
ax7 = plt.subplot2grid((2,4), (1,3))

# Input Arrays
n = np.array([0,1,2,3,4,5])
x = np.linspace(0,5,10)
xx = np.linspace(-0.75, 1., 100)

# Scatterplot
ax1.scatter(xx, xx + np.random.randn(len(xx)))
ax1.set_title("Scatter Plot")

# Step Chart
ax2.step(n, n**2, lw=2)
ax2.set_title("Step Plot")

# Bar Chart
ax3.bar(n, n**2, align="center", width=0.5, alpha=0.5)
ax3.set_title("Bar Chart")

# Fill Between
ax4.fill_between(x, x**2, x**3, color="steelblue", alpha=0.5);
ax4.set_title("Fill Between");

# Time Series
dates = pd.date_range('2018-01-01', periods = len(xx))
ax5.plot(dates, xx + np.random.randn(len(xx)))
ax5.set_xticks(dates[::30])
ax5.set_xticklabels(dates.strftime('%Y-%m-%d')[::30])
ax5.set_title("Time Series")

# Box Plot
ax6.boxplot(np.random.randn(len(xx)))
ax6.set_title("Box Plot")

# Histogram
ax7.hist(xx + np.random.randn(len(xx)))
ax7.set_title("Histogram")

fig.tight_layout()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\cbook\__init__.py:1402: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x[:, None]
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_base.py:276: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x = x[:, np.newaxis]

# %% [markdown]
# # 4. 圖例(Legend)設定

# %% [markdown]
# ### 法1

# %%
import matplotlib.pyplot as plt

plt.rcParams['font.sans-serif'] = ['SimHei']
x = range(2, 26, 2)
y = range(0, 12)
a = [5, 10, 15, 20, 25, 30]
b = [3, 4, 5, 6, 7, 8]

plt.plot(a, b, label = '序列a')
plt.plot(x, y, label = '序列b')

plt.legend(loc=2, edgecolor = 'red', facecolor = '#F5F5F5')
plt.show()

# %% [markdown]
# ### 法2

# %%
import matplotlib.pyplot as plt

plt.rcParams['font.sans-serif'] = ['SimHei']
x = range(2, 26, 2)
y = range(0, 12)
a = [5, 10, 15, 20, 25, 30]
b = [3, 4, 5, 6, 7, 8]

#由於 plt.plot 的回傳值不是一個單純的物件，line1 和 line2 後方一定要加上逗號。
line1, = plt.plot(a, b)
line2, = plt.plot(x, y)
line1.set_label('序列a')
line2.set_label('序列b')

plt.legend(loc=2, edgecolor = 'red', facecolor = '#F5F5F5')
plt.show()

# %% [markdown]
# ### 法3

# %%
import matplotlib.pyplot as plt

plt.rcParams['font.sans-serif'] = ['SimHei']
x = range(2, 26, 2)
y = range(0, 12)
a = [5, 10, 15, 20, 25, 30]
b = [3, 4, 5, 6, 7, 8]

plt.plot(a, b)
plt.plot(x, y)

plt.legend(['序列a', '序列b'], loc = 2, edgecolor = 'red', facecolor = '#F5F5F5')
plt.show()

# %% [markdown]
# ### 法4

# %%
import matplotlib.pyplot as plt

plt.rcParams['font.sans-serif'] = 'Microsoft Yahei'
x = range(2, 26, 2)
y = range(0, 12)
a = [5, 10, 15, 20, 25, 30]
b = [3, 4, 5, 6, 7, 8]

#由於 plt.plot 的回傳值一個物件，line1 和 line2 後方一定要加上逗號。
line1, = plt.plot(a, b)
line2, = plt.plot(x, y)

plt.legend((line1, line2), ('序列a', '序列b'), loc = 2, edgecolor = 'red', facecolor = '#F5F5F5')
plt.show()

# %% [markdown]
# ### 法5

# %%
import matplotlib.pyplot as plt

plt.rcParams['font.sans-serif'] = ['SimHei']
x = range(2, 26, 2)
y = range(0, 12)
a = [5, 10, 15, 20, 25, 30]
b = [3, 4, 5, 6, 7, 8]

#由於 plt.plot 的回傳值一個物件，line1 和 line2 後方一定要加上逗號。
line1, = plt.plot(a, b, label = '序列a')
line2, = plt.plot(x, y, label = '序列b')

plt.legend(handles = [line1, line2], loc = 2, edgecolor = 'red', facecolor = '#F5F5F5')
plt.show()

# %% [markdown]
# # 5. 區域填滿

# %% [markdown]
# plt.fill(x, y, color, alpha)
# - x：指定填滿的x區域
# - y：指定填滿的y區域
# - color：指定填滿顏色。
# - alpha：透明度0~1
# - 語法：https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.fill.html

# %%
# %pylab inline

x = np.linspace(0, 10)
y1 = x * np.sin(x)
y2 = x * np.cos(x)

plt.figure(figsize=(5,3))
plt.fill(x, y1, 'red', alpha=0.4)
plt.fill(x, y2, 'blue', alpha=0.4)
plt.xlabel('x axis yo!')
plt.ylabel("I don't even know")
# Out:
# Populating the interactive namespace from numpy and matplotlib
# Text(0, 0.5, "I don't even know")

# %% [markdown]
# plt.fill_between(x, y1, y2, where= y1 >= y2, facecolor = "red", interpolate= True, alpha = 0.5)
# - x：表示覆蓋的區域
# - y1：表示覆蓋的下限
# - y2：表示覆蓋的上限
# - where：過律條件，指定符合的情況進行繪圖
# - facecolor：覆蓋區域的顏色
# - interpolate：自動填充空白，當x取得離散點差距較大時，顯示的時候兩個函數之間的區域可能有空白存在，interpolate 就是用來填充這部分區域
# - alpha：覆蓋區域的透明度[0,1],其值越大，表示越不透明

# %%
# %pylab inline
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0, 5 * np.pi, 1000)

y1 = np.sin(x)
y2 = np.sin(2 * x)

plt.figure(figsize=(15,5))
plt.plot(x, y1, c = "g")
plt.plot(x, y2, c = 'r')

plt.fill_between(x, y1, y2, facecolor = "yellow") #fill_between
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # 6. 處理日期不連續繪圖

# %%
# !pip install pandas_datareader
# !pip install yfinance
# Out:
# ...
#      ------------------------------------ 109.5/109.5 kB 793.8 kB/s eta 0:00:00
# ...
#      -------------------------------------- 63.2/63.2 kB 481.2 kB/s eta 0:00:00
# ...
#      -------------------------------------- 112.2/112.2 kB 1.6 MB/s eta 0:00:00
# ...
#   Using cached requests-2.31.0-py3-none-any.whl (62 kB)
# ...
#   Attempting uninstall: requests
#     Found existing installation: requests 2.28.1
#     Uninstalling requests-2.28.1:
#       Successfully uninstalled requests-2.28.1
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# conda-repo-cli 1.0.41 requires requests_mock, which is not installed.
# conda-repo-cli 1.0.41 requires clyent==1.2.1, but you have clyent 1.2.2 which is incompatible.
# conda-repo-cli 1.0.41 requires nbformat==5.4.0, but you have nbformat 5.7.0 which is incompatible.
# ...

# %%
import pandas
from pandas_datareader import data as pdr
import yfinance as yfin

yfin.pdr_override()

start = '2022-12-01'
end = '2022-12-31'
df = pdr.DataReader('aapl', start, end)
df
# Out:
# [*********************100%***********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2022-12-01  148.210007  149.130005  146.610001  148.309998  147.679932
# 2022-12-02  145.960007  148.000000  145.649994  147.809998  147.182068
# 2022-12-05  147.770004  150.919998  145.770004  146.630005  146.007080
# 2022-12-06  147.070007  147.300003  141.919998  142.910004  142.302872
# 2022-12-07  142.190002  143.369995  140.000000  140.940002  140.341248
# 2022-12-08  142.360001  143.520004  141.100006  142.649994  142.043976
# 2022-12-09  142.339996  145.570007  140.899994  142.160004  141.556061
# 2022-12-12  142.699997  144.500000  141.059998  144.490005  143.876160
# 2022-12-13  149.500000  149.970001  144.240005  145.470001  144.852005
# 2022-12-14  145.350006  146.660004  141.160004  143.210007  142.601608
# 2022-12-15  141.110001  141.800003  136.029999  136.500000  135.920105
# ...

# %%
# %pylab inline

plt.rcParams['font.sans-serif'] = 'Microsoft YaHei'
plt.rcParams['axes.unicode_minus'] = False #用來正常顯示正負號

fig = plt.figure(figsize=(15, 8))
ax = fig.add_subplot(2, 1, 1)
ax.bar(df.index, df['Close'], label = '收盤價')
ax.legend(loc = 'upper right')
ax.set_xlabel('交易日')
ax.set_ylabel('收盤價')
ax.set_title('收盤價柱狀圖')
# Out:
# %pylab is deprecated, use %matplotlib inline and import the required libraries.
# Populating the interactive namespace from numpy and matplotlib
# Text(0.5, 1.0, '收盤價柱狀圖')

# %% [markdown]
# ### 法1

# %%
# %pylab inline
#import matplotlib.dates as mdates

plt.rcParams['font.sans-serif'] = 'Microsoft YaHei'
plt.rcParams['axes.unicode_minus'] = False #用來正常顯示正負號

fig = plt.figure(figsize=(15, 8))
ax = fig.add_subplot(2, 1, 1)

#ax.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
plt.xticks(range(len(df.index)), df.index, rotation = 30) #rotation表示x軸刻度旋轉度數

ax.bar(range(len(df.index)), df['Close'], label='收盤價')
ax.legend(loc = 'upper right')
ax.set_xlabel('交易日')
ax.set_ylabel('收盤價')
ax.set_title('收盤價柱狀圖')
# Out:
# %pylab is deprecated, use %matplotlib inline and import the required libraries.
# Populating the interactive namespace from numpy and matplotlib
# Text(0.5, 1.0, '收盤價柱狀圖')

# %% [markdown]
# ### 法2

# %%
# %pylab inline

plt.rcParams['font.sans-serif'] = 'Microsoft YaHei'
plt.rcParams['axes.unicode_minus'] = False #用來正常顯示正負號

fig = plt.figure(figsize = (15, 4))
ax = fig.subplots(1)

ax.set_xticks(range(len(df.index)))
ax.set_xticklabels(df.index, rotation = 30)

ax.bar(range(len(df.index)), df['Close'], label='收盤價')
ax.legend(loc = 'upper right')
ax.set_xlabel('交易日')
ax.set_ylabel('收盤價')
ax.set_title('收盤價柱狀圖')
# Out:
# %pylab is deprecated, use %matplotlib inline and import the required libraries.
# Populating the interactive namespace from numpy and matplotlib
# Text(0.5, 1.0, '收盤價柱狀圖')
